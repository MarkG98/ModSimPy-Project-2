# %%
# %matplotlib inline

from modsim import *

# %%
tc_h= 3
tc_m=2
tc_nm=1         #time between contacts in days
tr=4        #recovery time in days
th=2         #time sick but appear healthy in days

beta_h=1/tc_h
beta_m=1/tc_m
beta_nm=1/tc_nm      #contact rate in per day
gamma=1/tr      #recovery rate in per day
omega=1/th      #sick appearance rate in per day

alpha = .1  #percent of sick people who take medicine
alpha_array = linspace(0.1, 0.9, 21)

credits = 16
hours_expected = credits * 3

hours_s = 48
hours_i_h = 48
hours_i_nm = 12
hours_i_m = 30
hours_r = 48

total_hours_expected = hours_expected * 350

# %%
def make_system(beta_h, beta_m, beta_nm, gamma, omega, alpha):
    """Make a system object for the SIR model.
    
    beta: contact rate in days
    gamma: recovery rate in days
    
    returns: System object
    """
    init = State(S=349, I_H=1, I_M=0, I_NM=0, R=0)
    init /= np.sum(init)
    
    initE = State(Se=349 * 48, I_He=1 * 48, I_Me=0, I_NMe=0, Re=0, Efficiancy = 0)
    
    t0 = 0
    t_end = 7 * 14

    return System(init=init, initE=initE, t0=t0, t_end=t_end,
                  beta_h=beta_h, beta_m=beta_m, beta_nm=beta_nm, gamma=gamma, omega=omega, alpha=alpha)

# %%
def plot_results(S, I_H, I_M, I_NM, R):
    """Plot the results of a SIR model.
    
    S: TimeSeries
    I: TimeSeries
    I_H: TimeSeries
    I_U: TimeSeries
    R: TimeSeries
    """
    plot(S, '--', color='blue', label='s')
    plot(I_H, '-', color='red', label='i_h')
    plot(I_M, '-', color='purple', label='i_m')
    plot(I_NM, '-', color='orange', label='i_nm')
    plot(R, ':', color='green', label='r')
    decorate(xlabel='Time (days)',
             ylabel='Fraction of population')

# %%
def calc_total_infected(system):
    """Fraction of population infected during the simulation.
    
    system: System object with results.
    
    returns: fraction of population
    """
    frame = system.results
    return frame.S[system.t0] - frame.S[system.t_end]

# %%
def calculate_efficiancy(stateE, stateP, system):
    
    Se, I_He, I_Me, I_NMe, Re, Efficiancy = stateE
    
    s, i_h, i_m, i_nm, r = stateP
        
    Se = (hours_s) * s * 350
    I_He = (hours_i_h) * i_h * 350
    I_Me = (hours_i_m) * i_m * 350
    I_NMe = (hours_i_nm) * i_nm * 350
    Re = (hours_r) * r * 350  
    
    Efficiancy = total_hours_expected - Se - I_He - I_Me - I_NMe - Re 
    
    return State(Se=Se, I_He=I_He, I_Me=I_Me, I_NMe=I_NMe, Re=Re, Efficiancy=Efficiancy)

# %%
def calculate_duration(system):
    system[0]=0;
    system[1]=0
    for i in linrange(3,100):
        system[i] = round(system[i],3)
        if system[i]==system[i-1]:
            return i-1

# %%
"""def calculate_efficiancy(stateE, stateP, stateH, system):
    
    Se, I_He, I_Me, I_NMe, Re = stateE
    
    s, i_h, i_m, i_nm, r = stateP
    
    Total_Hours_Exp = stateH
    
    Se = (hours_s) * s * 350
    I_He = (hours_i_h) * i_h * 350
    I_Me = (hours_i_m) * i_m * 350
    I_NMe = (hours_i_nm) * i_nm * 350
    Re = (hours_r) * r * 350
    
    Total_Hours_Exp = total_hours_expected - Se - I_He - I_Me - I_NMe - Re    
    
    return State(HT=Total_Hours_Exp)"""
# Out:
# 'def calculate_efficiancy(stateE, stateP, stateH, system):\n    \n    Se, I_He, I_Me, I_NMe, Re = stateE\n    \n    s, i_h, i_m, i_nm, r = stateP\n    \n    Total_Hours_Exp = stateH\n    \n    Se = (hours_s) * s * 350\n    I_He = (hours_i_h) * i_h * 350\n    I_Me = (hours_i_m) * i_m * 350\n    I_NMe = (hours_i_nm) * i_nm * 350\n    Re = (hours_r) * r * 350\n    \n    Total_Hours_Exp = total_hours_expected - Se - I_He - I_Me - I_NMe - Re    \n    \n    return State(HT=Total_Hours_Exp)'

# %%
def run_simulation(system, update_func, eff_func):
    """Runs a simulation of the system.
    
    Add a TimeFrame to the System: results
    
    system: System object
    update_func: function that updates state
    """
    
    frame = TimeFrame(columns=system.init.index)
    frame.loc[system.t0] = system.init
    
    eff = TimeFrame(columns=system.initE.index)
    eff.loc[system.t0] = system.initE
    
    
    for i in linrange(system.t0, system.t_end):
        frame.loc[i+1] = update_func(frame.loc[i], system)
        eff.loc[i+1] = eff_func(eff.loc[i], frame.loc[i], system) 
        
        
    system.results = frame
    system.resultsE = eff

# %%
def update1(state, system):
    """Update the SIR model.
    
    state: State (s, i, r)
    system: System object
    
    returns: State (sir)
    """

    s, i_h, i_m, i_nm, r = state

    # Infected-Healthy
    #still_IH = i_h * omega
    new_IH = s * ((i_h * system.beta_h) + (i_m * system.beta_m) + (i_nm * system.beta_nm))
    #infected_Healthy = still_IH + new_IH
    
    # Infected-Medicine
    #still_IM = (1-gamma)*i_m
    new_IM = system.alpha * i_h * (system.omega)
    #infected_Med = still_IM + new_IM
    
    # Infected-NoMedicine
    #stillNM = (1-gamma)*i_nm
    newNM = (1 - system.alpha)*i_h*(system.omega)
    #infected_No_Med = stillNM + newNM
    
    recovered = system.gamma * (i_m + i_nm)
    
    s -= new_IH
    i_h +=  new_IH - newNM - new_IM
    i_m += new_IM - (recovered * system.alpha)
    i_nm += newNM - (recovered*(1 - system.alpha))
    r += recovered
    
    return State(S=s, I_H=i_h, I_M=i_m, I_NM=i_nm, R=r)

# %%
system = make_system(beta_h, beta_m, beta_nm, gamma, omega, alpha)
run_simulation(system, update1, calculate_efficiancy)
system.resultsE
# Out:
#               Se          I_He          I_Me        I_NMe            Re  \
# 0   16752.000000  4.800000e+01  0.000000e+00     0.000000      0.000000
# 1   16752.000000  4.800000e+01  0.000000e+00     0.000000      0.000000
# 2   16736.045714  3.995429e+01  1.500000e+00     5.400000      0.000000
# 3   16700.065114  5.595774e+01  2.373571e+00     8.544857      6.000000
# 4   16645.659813  8.238417e+01  3.528858e+00    12.703889     15.494286
# 5   16565.304839  1.215471e+02  5.221149e+00    18.796136     29.609718
# 6   16447.102367  1.789760e+02  7.714207e+00    27.771146     50.494314
# 7   16273.903984  2.626864e+02  1.137866e+01    40.963160     81.351143
# 8   16021.544465  3.837027e+02  1.674294e+01    60.274588    126.865765
# 9   15656.869690  5.565261e+02  2.454792e+01    88.372496    193.837530
# 10  15136.244265  7.988885e+02  3.580238e+01   128.888562    292.029192
# 11  14406.017501  1.129671e+03  5.181705e+01   186.541377    435.238705
# 12  13407.735241  1.563118e+03  7.416501e+01   266.994021    642.506902
# 13  12092.223052  2.097071e+03  1.044712e+02   376.096264    939.166925
# 14  10446.107509  2.694651e+03  1.438869e+02   517.992694   1357.051663
# 15   8527.693987  3.265739e+03  1.921230e+02   691.642767   1932.599100
# 16   6492.798822  3.667765e+03  2.461466e+02   886.127719   2701.091063
# 17   4574.325030  3.752356e+03  2.992276e+02  1077.219318   3685.677418
# 18   2995.353874  3.455149e+03  3.416818e+02  1230.054554   4882.587771
# 19   1864.022965  2.858906e+03  3.642348e+02  1311.245203   6249.315053
# 20   1144.006687  2.149469e+03  3.625169e+02  1305.060774   7706.254168
# 21    719.992438  1.498749e+03  3.390586e+02  1220.610847   9156.321695
# 22    477.711847  9.916550e+02  3.011298e+02  1084.067372  10512.555969
# 23    338.159563  6.353798e+02  2.568366e+02   924.611714  11717.075271
# 24    255.316320  4.005331e+02  2.124831e+02   764.939010  12744.421620
# 25    204.203611  2.513793e+02  1.718790e+02   618.764234  13594.353853
# 26    171.429500  1.584637e+02  1.367648e+02   492.353344  14281.869668
# 27    149.677887  1.009835e+02  1.075256e+02   387.092180  14828.928939
# 28    134.816563  6.535307e+01  8.379994e+01   301.679777  15259.031361
# 29    124.420092  4.307300e+01  6.489224e+01   233.612053  15594.231113
# ..           ...           ...           ...          ...           ...
# 70     96.100567  3.068523e-04  9.126308e-04     0.003285  16703.884524
# 71     96.100487  2.333628e-04  6.940622e-04     0.002499  16703.888175
# 72     96.100426  1.774737e-04  5.278393e-04     0.001900  16703.890951
# 73     96.100380  1.349698e-04  4.014255e-04     0.001445  16703.893062
# 74     96.100345  1.026454e-04  3.052869e-04     0.001099  16703.894668
# 75     96.100318  7.806249e-05  2.321729e-04     0.000836  16703.895889
# 76     96.100298  5.936703e-05  1.765691e-04     0.000636  16703.896818
# 77     96.100282  4.514903e-05  1.342820e-04     0.000483  16703.897524
# 78     96.100270  3.433614e-05  1.021224e-04     0.000368  16703.898061
# 79     96.100262  2.611287e-05  7.766484e-05     0.000280  16703.898470
# 80     96.100255  1.985902e-05  5.906465e-05     0.000213  16703.898780
# 81     96.100250  1.510292e-05  4.491908e-05     0.000162  16703.899017
# 82     96.100246  1.148587e-05  3.416128e-05     0.000123  16703.899196
# 83     96.100243  8.735087e-06  2.597989e-05     0.000094  16703.899333
# 84     96.100240  6.643095e-06  1.975789e-05     0.000071  16703.899437
# 85     96.100239  5.052120e-06  1.502602e-05     0.000054  16703.899516
# 86     96.100237  3.842173e-06  1.142739e-05     0.000041  16703.899576
# 87     96.100236  2.921999e-06  8.690611e-06     0.000031  16703.899622
# 88     96.100236  2.222201e-06  6.609270e-06     0.000024  16703.899656
# 89     96.100235  1.689999e-06  5.026397e-06     0.000018  16703.899683
# 90     96.100235  1.285256e-06  3.822610e-06     0.000014  16703.899703
# 91     96.100234  9.774465e-07  2.907122e-06     0.000010  16703.899718
# 92     96.100234  7.433549e-07  2.210886e-06     0.000008  16703.899730
# 93     96.100234  5.653266e-07  1.681395e-06     0.000006  16703.899739
# 94     96.100234  4.299349e-07  1.278712e-06     0.000005  16703.899746
# 95     96.100233  3.269685e-07  9.724697e-07     0.000004  16703.899751
# 96     96.100233  2.486618e-07  7.395700e-07     0.000003  16703.899755
# 97     96.100233  1.891091e-07  5.624482e-07     0.000002  16703.899757
# 98     96.100233  1.438188e-07  4.277458e-07     0.000002  16703.899760
# 99     96.100233  1.093752e-07  3.253036e-07     0.000001  16703.899761
#
#      Efficiancy
# 0      0.000000
# 1      0.000000
# 2     17.100000
# 3     27.058714
# 4     40.228982
# 5     59.521098
# 6     87.941963
# 7    129.716673
# 8    190.869530
# 9    279.846238
# 10   408.147113
# 11   590.714359
# 12   845.481066
# 13  1190.971503
# 14  1640.310196
# 15  2190.202094
# 16  2806.071111
# 17  3411.194506
# 18  3895.172754
# 19  4152.276477
# 20  4132.692450
# 21  3865.267683
# 22  3432.880011
# 23  2927.937093
# 24  2422.306864
# 25  1959.420075
# 26  1559.118923
# 27  1225.791902
# 28   955.319293
# 29   739.771500
# ..          ...
# 70     0.010404
# 71     0.007912
# 72     0.006017
# 73     0.004576
# 74     0.003480
# 75     0.002647
# 76     0.002013
# 77     0.001531
# 78     0.001164
# 79     0.000885
# 80     0.000673
# 81     0.000512
# 82     0.000389
# 83     0.000296
# 84     0.000225
# 85     0.000171
# 86     0.000130
# 87     0.000099
# 88     0.000075
# 89     0.000057
# 90     0.000044
# 91     0.000033
# 92     0.000025
# 93     0.000019
# 94     0.000015
# 95     0.000011
# 96     0.000008
# 97     0.000006
# 98     0.000005
# 99     0.000004
#
# [100 rows x 6 columns]

# %%
Recovered= system.results.R
type (Recovered)
# Out:
# pandas.core.series.Series

# %%
Recovered
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000357
# 3     0.000922
# 4     0.001762
# 5     0.003006
# 6     0.004842
# 7     0.007552
# 8     0.011538
# 9     0.017383
# 10    0.025907
# 11    0.038244
# 12    0.055903
# 13    0.080777
# 14    0.115036
# 15    0.160779
# 16    0.219386
# 17    0.290630
# 18    0.371983
# 19    0.458706
# 20    0.545019
# 21    0.625747
# 22    0.697445
# 23    0.758597
# 24    0.809188
# 25    0.850111
# 26    0.882674
# 27    0.908276
# 28    0.928228
# 29    0.943679
#         ...
# 70    0.994279
# 71    0.994279
# 72    0.994279
# 73    0.994279
# 74    0.994280
# 75    0.994280
# 76    0.994280
# 77    0.994280
# 78    0.994280
# 79    0.994280
# 80    0.994280
# 81    0.994280
# 82    0.994280
# 83    0.994280
# 84    0.994280
# 85    0.994280
# 86    0.994280
# 87    0.994280
# 88    0.994280
# 89    0.994280
# 90    0.994280
# 91    0.994280
# 92    0.994280
# 93    0.994280
# 94    0.994280
# 95    0.994280
# 96    0.994280
# 97    0.994280
# 98    0.994280
# 99    0.994280
# Name: R, Length: 100, dtype: float64

# %%
calculate_duration(Recovered)
# Out:
# 40.0

# %% [markdown]
# ##

# %%
frame = system.results
plot_results(frame.S, frame.I_H, frame.I_M, frame.I_NM, frame.R)
savefig('sim-run.pdf')
# Out:
# Saving figure to file sim-run.pdf

# %%
def plot_results2(Efficiancy):
    """Plot the results of a SIR model.
    
    S: TimeSeries
    I: TimeSeries
    I_H: TimeSeries
    I_U: TimeSeries
    R: TimeSeries
    """
    plot(Efficiancy, '--', color='blue', label='E')
    decorate(xlabel='Time (days)',
             ylabel='Time Lost (Hours)')

# %%
eff = system.resultsE
plot_results2(eff.Efficiancy)
savefig('Hours-Lost.pdf')
# Out:
# Saving figure to file Hours-Lost.pdf

# %%
def add_hours(column):
    total = 0
    i = 0
    for hours in column:
        total += hours
    return total

# %%
def sweep_alpha(beta_h, beta_m, beta_nm, gamma, omega, alpha_array):
    """SweepSeriess a range of values for alpha.
    
    alpha_array: array of alpha values
    gamma: recovery rate
    
    returns: SweepSeries that maps from beta to total infected
    """
    sweep = SweepSeries()
    for alpha in alpha_array:
        system = make_system(beta_h, beta_m, beta_nm, gamma, omega, alpha)
        run_simulation(system, update1, calculate_efficiancy)
        
        sweep[system.alpha] = add_hours(system.resultsE.Efficiancy)
    return sweep

# %%
efficiancy_sweep = sweep_alpha(beta_h, beta_m, beta_nm, gamma, omega, alpha_array)
efficiancy_sweep
# Out:
# 0.100000    47606.114324
# 0.126667    46914.939953
# 0.153333    46222.660485
# 0.180000    45529.226834
# 0.206667    44834.588529
# 0.233333    44138.693714
# 0.260000    43441.489160
# 0.286667    42742.920276
# 0.313333    42042.931127
# 0.340000    41341.464461
# 0.366667    40638.461734
# 0.393333    39933.863154
# 0.420000    39227.607722
# 0.446667    38519.633292
# 0.473333    37809.876632
# 0.500000    37098.273508
# 0.526667    36384.758775
# 0.553333    35669.266482
# 0.580000    34951.730001
# 0.606667    34232.082175
# 0.633333    33510.255487
# 0.660000    32786.182255
# 0.686667    32059.794867
# 0.713333    31331.026036
# 0.740000    30599.809112
# 0.766667    29866.078432
# 0.793333    29129.769722
# 0.820000    28390.820568
# 0.846667    27649.170958
# 0.873333    26904.763900
# 0.900000    26157.546148
# dtype: float64

# %%
plot(efficiancy_sweep)
decorate(xlabel='Percent of Population Taking Cold Medicine (alpha)',
         ylabel='Total Hours Lost in System')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
def sweep_alpha2(beta_h, beta_m, beta_nm, gamma, omega, alpha_array):
    """SweepSeriess a range of values for alpha.
    
    alpha_array: array of alpha values
    gamma: recovery rate
    
    returns: SweepSeries that maps from beta to total infected
    """
    sweep = SweepFrame()
    #sweep2 = SweepSeries()
    for alpha in alpha_array:
        system = make_system(beta_h, beta_m, beta_nm, gamma, omega, alpha)
        run_simulation(system, update1, calculate_efficiancy)
        recovered = system.results.R
        # print (recovered)
        num = calculate_duration(recovered)
        sweep[alpha] = add_hours(system.resultsE.Efficiancy), num
        # sweep2[alpha] = num
        print (num)
    return sweep

# %%
sweep = sweep_alpha2(beta_h, beta_m, beta_nm, gamma, omega, alpha_array)

sweep
# Out:
# 40.0
# 40.0
# 40.0
# 42.0
# 42.0
# 40.0
# 42.0
# 43.0
# 43.0
# 43.0
# 44.0
# 45.0
# 46.0
# 46.0
# 47.0
# 47.0
# 47.0
# 48.0
# 50.0
# 50.0
# 51.0
#            0.10          0.14          0.18         0.22         0.26  \
# 0  47606.114324  46568.941391  45529.226834  44486.80148  43441.48916
# 1     40.000000     40.000000     40.000000     42.00000     42.00000
#
#            0.30          0.34          0.38          0.42          0.46  \
# 0  42393.106783  41341.464461  40286.365711  39227.607722  38164.981733
# 1     40.000000     42.000000     43.000000     43.000000     43.000000
#
#        ...               0.54          0.58          0.62          0.66  \
# 0      ...       36027.263973  34951.730001  33871.445418  32786.182255
# 1      ...          45.000000     46.000000     46.000000     47.000000
#
#            0.70          0.74          0.78          0.82          0.86  \
# 0  31695.712316  30599.809112  29498.250281  28390.820568  27277.315534
# 1     47.000000     47.000000     48.000000     50.000000     50.000000
#
#            0.90
# 0  26157.546148
# 1     51.000000
#
# [2 rows x 21 columns]

# %%
#sweep2

# %%
plot(sweep.loc[1], sweep.loc[0], 'bo')
decorate(xlabel='Length of Infection',
         ylabel='Total Hours Lost in System')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
